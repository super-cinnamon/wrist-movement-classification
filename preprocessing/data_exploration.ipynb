# %% [markdown]
# # Init

# %% [markdown]
# ## Imports

# %%
import os
import json

import pandas as pd
from skimpy import skim

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Variables & Constants

# %%
data_dir = "data"
dataset_file_name = "processed_dataset.csv"
moves_file_name = "individual_moves.csv"

DATA_PATH = os.path.join(os.getcwd(), '..', data_dir)

DATASET_FILE = os.path.join(DATA_PATH, dataset_file_name)
MOVES_FILE = os.path.join(DATA_PATH, moves_file_name)

# %%
dataset = pd.read_csv(DATASET_FILE)
moves = pd.read_csv(MOVES_FILE)
dataset
# Out:
#      maxroll  maxpitch  maxyaw  minroll  minpitch  minyaw    avgroll  \
# 0      43.85     80.49   42.61    -5.39     23.93    1.33  12.319824
# 1      72.96     18.22   70.69    -0.63     -5.84   -2.04  25.030914
# 2      17.27     55.41   41.88   -41.23    -66.60  -36.21  -9.929293
# 3      68.65     23.47   75.21    -5.32     -3.91   -0.04  30.158000
# 4      51.33     56.31   37.56   -44.67    -52.19  -32.02   5.681686
# ..       ...       ...     ...      ...       ...     ...        ...
# 135   -62.25    -10.26   88.23  -112.97    -43.12  -11.05 -79.514354
# 136     7.67     32.83   41.41   -25.22     14.04   38.31 -18.763529
# 137     0.11     44.76   15.57   -92.38     -0.22    0.52 -29.392887
# 138    83.10     47.18  -58.38   -60.51     36.95  -67.43  11.297468
# 139   -10.09     -1.93    1.76   -73.02    -17.60  -41.66 -57.018363
#
#       avgpitch     avgyaw  ranroll  ranpitch  ranyaw  skewroll  skewpitch  \
# 0    62.942952  29.667269    49.24     56.56   41.28  1.203729  -0.800003
# 1     4.634355  26.041828    73.59     24.06   72.73  0.595637   0.525465
# 2    -2.049242   2.437727    58.50    122.01   78.09 -0.135859   0.124499
# 3     9.358486  38.373027    73.97     27.38   75.25  0.113072   0.007730
# 4     1.191744  -2.348023    96.00    108.50   69.58 -0.045629   0.089485
# ..         ...        ...      ...       ...     ...       ...        ...
# 135 -32.756268  26.617368    50.72     32.86   99.28 -0.934435   0.787635
# 136  15.870245  39.986814    32.89     18.79    3.10  1.735318   2.785254
# 137  17.131338   8.068944    92.49     44.98   15.05 -0.667809   0.435873
# 138  40.904156 -64.332662   143.61     10.23    9.05  0.046274   0.789349
# 139 -10.000044 -19.297920    62.93     15.67   43.42  1.621116  -0.475270
#
#       skewyaw  class
# 0   -0.748625      1
# 1    0.450947      1
# 2    0.039518      1
# 3   -0.103531      1
# 4    0.468553      1
# ..        ...    ...
# 135  0.559939      0
# 136  0.050231      0
# 137 -0.251676      0
# 138  1.025757      0
# 139 -0.097134      0
#
# [140 rows x 16 columns]

# %%
skim(dataset)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 140    │ │ float64     │ 15    │                                                          │
# │ │ Number of columns │ 16     │ │ int32       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name  ┃ NA  ┃ NA %  ┃ mean      ┃ sd      ┃ p0      ┃ p25     ┃ p50      ┃ p75     ┃ p100  ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━┩  │
# │ │ maxroll      │   0 │     0 │     27.62 │   28.78 │  -62.25 │    2.53 │    31.88 │   50.94 │  83.1 │  ▁▇▃▇▃ │  │
# │ │ maxpitch     │   0 │     0 │     30.31 │   26.76 │   -61.8 │   14.28 │    29.98 │   44.59 │ 105.7 │  ▁▆▇▃▁ │  │
# │ │ maxyaw       │   0 │     0 │     54.41 │   43.21 │  -58.38 │   28.53 │    50.06 │   72.03 │ 278.5 │  ▁▇▆▁  │  │
# │ │ minroll      │   0 │     0 │    -41.03 │   36.26 │  -149.9 │  -70.55 │   -36.69 │  -8.015 │ 39.21 │  ▃▅▅▇▁ │  │
# │ │ minpitch     │   0 │     0 │    -19.21 │   30.09 │  -101.2 │  -40.13 │      -11 │ -0.6225 │ 68.16 │ ▁▃▃▇▁  │  │
# │ │ minyaw       │   0 │     0 │    -5.827 │   43.05 │  -108.7 │  -27.69 │    -0.56 │   7.815 │ 205.7 │  ▂▅▇▁  │  │
# │ │ avgroll      │   0 │     0 │    -6.899 │    31.5 │  -111.1 │  -32.55 │   -3.601 │    19.6 │ 49.11 │  ▁▇▇▇▇ │  │
# │ │ avgpitch     │   0 │     0 │     5.452 │   24.93 │  -73.22 │  -9.413 │     6.21 │   19.84 │ 77.45 │  ▂▅▇▂▁ │  │
# │ │ avgyaw       │   0 │     0 │     25.62 │   41.51 │  -64.33 │   3.935 │    26.04 │   43.27 │ 245.8 │  ▂▇▃▁  │  │
# │ │ ranroll      │   0 │     0 │     68.64 │   31.63 │   11.13 │   48.89 │    64.66 │   83.56 │ 161.4 │ ▅▇▇▃▃▁ │  │
# │ │ ranpitch     │   0 │     0 │     49.52 │   29.37 │    5.59 │   27.95 │    45.34 │   64.53 │ 159.8 │ ▆▇▅▁▁  │  │
# │ │ ranyaw       │   0 │     0 │     60.23 │   33.32 │    2.14 │   38.72 │    56.59 │   77.84 │ 180.9 │ ▅▇▆▂▁  │  │
# │ │ skewroll     │   0 │     0 │   0.06681 │  0.5617 │  -1.167 │ -0.2826 │  0.04232 │  0.3529 │ 1.735 │ ▂▅▇▅▂▁ │  │
# │ │ skewpitch    │   0 │     0 │   0.06687 │  0.6763 │  -2.284 │ -0.3231 │  0.03105 │  0.4067 │ 2.785 │  ▂▇▅▁  │  │
# │ │ skewyaw      │   0 │     0 │  -0.08678 │   0.546 │  -2.154 │ -0.4319 │ -0.07127 │  0.3344 │ 1.054 │   ▃▇▇▃ │  │
# │ │ class        │   0 │     0 │      0.65 │  0.4787 │       0 │       0 │        1 │       1 │     1 │ ▅    ▇ │  │
# │ └──────────────┴─────┴───────┴───────────┴─────────┴─────────┴─────────┴──────────┴─────────┴───────┴────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
moves.roll = moves.roll.apply(json.loads)
moves.pitch = moves.pitch.apply(json.loads)
moves.yaw = moves.yaw.apply(json.loads)
moves
# Out:
#                                                   roll  \
# 0    [2.78, 2.79, 2.82, 2.83, 2.86, 2.87, 2.88, 2.9...
# 1    [-0.02, -0.03, -0.06, -0.06, -0.02, -0.04, -0....
# 2    [-1.82, -1.73, -1.61, -1.5, -1.38, -1.31, -1.2...
# 3    [-0.48, -0.5, -0.51, -0.51, -0.47, -0.46, -0.4...
# 4    [-44.64, -44.67, -44.41, -43.86, -43.06, -42.0...
# ..                                                 ...
# 135  [-67.72, -67.72, -67.71, -67.72, -67.71, -67.7...
# 136  [7.23, 7.47, 7.62, 7.67, 7.63, 7.52, 7.37, 7.1...
# 137  [-0.28, -0.28, -0.29, -0.29, -0.28, -0.27, -0....
# 138  [-60.41, -60.37, -60.34, -60.36, -60.4, -60.42...
# 139  [-10.16, -10.21, -10.2, -10.21, -10.17, -10.09...
#
#                                                  pitch  \
# 0    [79.91, 79.93, 79.93, 79.96, 79.96, 79.96, 79....
# 1    [-0.42, -0.39, -0.42, -0.45, -0.48, -0.44, -0....
# 2    [-12.17, -11.98, -11.84, -11.72, -11.62, -11.5...
# 3    [-0.57, -0.58, -0.6, -0.6, -0.61, -0.61, -0.61...
# 4    [-42.2, -42.27, -42.36, -42.37, -42.34, -42.3,...
# ..                                                 ...
# 135  [-43.11, -43.11, -43.11, -43.1, -43.12, -43.1,...
# 136  [32.83, 31.93, 30.95, 30.13, 29.36, 28.56, 27....
# 137  [0.99, 1.0, 1.0, 0.98, 0.97, 0.97, 0.95, 0.94,...
# 138  [46.79, 46.76, 46.78, 46.77, 46.78, 46.83, 46....
# 139  [-15.97, -16.01, -16.05, -16.16, -16.23, -16.4...
#
#                                                    yaw  class
# 0    [42.61, 42.59, 42.58, 42.57, 42.57, 42.57, 42....      1
# 1    [-0.68, -0.68, -0.67, -0.67, -0.67, -0.67, -0....      1
# 2    [15.72, 15.74, 15.76, 15.76, 15.75, 15.73, 15....      1
# 3    [-0.04, -0.02, 0.0, 0.02, 0.03, 0.05, 0.06, 0....      1
# 4    [-24.64, -24.47, -24.3, -24.16, -24.06, -23.97...      1
# ..                                                 ...    ...
# 135  [-4.72, -4.74, -4.75, -4.75, -4.75, -4.75, -4....      0
# 136  [39.42, 39.27, 39.2, 39.21, 39.29, 39.43, 39.5...      0
# 137  [0.52, 0.53, 0.53, 0.54, 0.54, 0.55, 0.57, 0.5...      0
# 138  [-65.22, -65.25, -65.28, -65.31, -65.35, -65.3...      0
# 139  [-24.76, -24.76, -24.75, -24.73, -24.69, -24.6...      0
#
# [140 rows x 4 columns]

# %%
skim(moves)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 140    │ │ int32       │ 1     │                                                          │
# │ │ Number of columns │ 1      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name       ┃ NA   ┃ NA %    ┃ mean    ┃ sd        ┃ p0   ┃ p25   ┃ p50   ┃ p75   ┃ p100   ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━━┩  │
# │ │ class             │    0 │       0 │    0.65 │    0.4787 │    0 │     0 │     1 │     1 │      1 │ ▅    ▇  │  │
# │ └───────────────────┴──────┴─────────┴─────────┴───────────┴──────┴───────┴───────┴───────┴────────┴─────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Individual moves visualization

# %%
random_0 = moves[moves["class"] == 0].sample(1)

# %%
random_1 = moves[moves["class"] == 1].sample(1)

# %%
# create line plot for each
sns.lineplot(y=random_0.roll.iloc[0], x=range(len(random_0.roll.iloc[0])), errorbar=None)
sns.lineplot(y=random_0.pitch.iloc[0], x=range(len(random_0.pitch.iloc[0])), errorbar=None)
sns.lineplot(y=random_0.yaw.iloc[0], x=range(len(random_0.yaw.iloc[0])), errorbar=None)

plt.legend(["roll", "pitch", "yaw"])

# %%
# create line plot for each
sns.lineplot(y=random_1.roll.iloc[0], x=range(len(random_1.roll.iloc[0])), errorbar=None)
sns.lineplot(y=random_1.pitch.iloc[0], x=range(len(random_1.pitch.iloc[0])), errorbar=None)
sns.lineplot(y=random_1.yaw.iloc[0], x=range(len(random_1.yaw.iloc[0])), errorbar=None)

plt.legend(["roll", "pitch", "yaw"])

# %% [markdown]
# ## Dataset visualization

# %% [markdown]
# ### Box plots

# %%
# Create a figure with 5 rows and 3 columns
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 10))

# Iterate over the columns, skipping the last one
for i, col in enumerate(dataset.columns[:-1]):
    row = i // 3
    col_idx = i % 3
    sns.boxplot(x=dataset[col], ax=axes[row, col_idx])
    axes[row, col_idx].set_title(col)

# Adjust spacing between subplots
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Distribution

# %%
dataset["class"].value_counts()
# Out:
# class
# 1    91
# 0    49
# Name: count, dtype: int64

# %%
# class distribution
sns.histplot(dataset["class"], bins=3)
plt.xticks([0, 1])
# Out:
# ([<matplotlib.axis.XTick at 0x236440e5a10>,
#   <matplotlib.axis.XTick at 0x236440d1910>],
#  [Text(0, 0, '0'), Text(1, 0, '1')])

# %% [markdown]
# ### Correlation

# %%
correlation_matrix = dataset.corr()
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >
